# %% [markdown]
# # Visual Python을 활용한 머신러닝 실습
# * 순서
#   1. 데이터 수집
#   2. 데이터 전처리 및 train_test_split
#   3. 모델 생성
#   4. 훈련 fit
#   5. 예측 predict
#   6. 평가 evaluation
#   7. 시각화
# * (실습) RandomForest 예측모델
# *

# %% [markdown]
# ## 환경구성 : Chart Style
# ![image.png](attachment:4e2fce43-3acd-4eca-bbc9-b54f3c407de0.png)

# %%
# (선수조건) 챠트 환경 설정

# %% [markdown]
# ## 환경구성: Package 추가 : Import => Machine Learning
# ![image.png](attachment:9a07b39a-d503-4a56-8533-7a4968227ba1.png)

# %%
# (선수조건) Machine Learning 패키지 추가
# from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## 1. 데이터 수집 : Data Sets
# <img src="attachment:e65334e5-e815-4d31-8f8e-44cbf7f0f1ec.png" width=500px height=500px />

# %%
# 1. 데이터 수집

# %% [markdown]
# ## 2. 데이터 전처리 및 train_test_split
# 1. Frame 선택
#    ![image.png](attachment:ed5cae8a-eef9-4b82-bd06-380a2e797fd7.png)
# 2. 독립변수 선택: df
#     > df_ldata DataFrame에서 target 속성을 제거하고 df로 복사
#     > <img src="attachment:885002e5-a31c-4a0e-af41-4d96deb65fee.png" width=700px height=500px />
#     >

# %%
# 2-1. 데이터 전처리(독립변수) 및 train_test_split

# %% [markdown]
# ## 2. 데이터 전처리 및 train_test_split
# 3. Subset 선택  : ![image.png](attachment:c5a3b298-c05d-4a75-ac58-b0a6c3bf03fd.png)
# 4. 종속변수 선택: y
#    > 수집된 데이터(df_ldata)에서 종속변수(y) 추출
#    > ![image.png](attachment:e3c55853-4973-4de8-86f8-510ab47bd81e.png)
#    >

# %%
# 2-2. 데이터 전처리(종속변수 y) 및 train_test_split

# %% [markdown]
# ## 2. 데이터 전처리 및 train_test_split
# 5. train_test_split : ![image.png](attachment:5b5186be-5a7b-44fe-a987-8dec935eed9d.png) 선택
#    >  train : test 비율 => 7 : 3
#    >  <img src="attachment:11d0120f-13d6-4236-8d6e-ff6565379bed.png" width=500px height=500px />
#    >

# %%
# 2-3. 데이터 전처리 및 train_test_split

# %% [markdown]
# ## 3. 머신러닝 모델 생성
# 1. 모델 선택 : ![image.png](attachment:f3c779be-d057-4d17-a03f-93553de07e79.png)
#    > <img src="attachment:875ec89d-dd50-4206-99d1-428003dc4e0c.png" width=500px height=500px />
#    >

# %%
# 3. 모델 생성(RandomForestClassifier)

# %% [markdown]
# ## 4. 학습 fit
# * 모델 훈련
#   > ![image.png](attachment:fa3956f5-b1b6-4e83-940d-4a20647844f7.png)

# %%
# 4. 학습(fit)

# %% [markdown]
# ## 5. 예측 predict
# * 예측
#   > ![image.png](attachment:b14fffdf-6a92-462a-9604-727dd52def79.png)
#   >
#   > 테스트데이터: X_test
#   > 예측결과: pred

# %%
# 5. 예측(predict)

# %% [markdown]
# ## 6. 평가 : evaluation
# * 평가
#   > ![image.png](attachment:b3a9b071-8728-4d5f-8cfe-469125356e9a.png)

# %%
# 6. 평가(Evaluation) : Accuracy(정확성)

# %% [markdown]
# ## 7. 시각화(표, features importance)
# * ![image.png](attachment:b936b616-06b9-4be8-a93a-102dd7f33466.png)
#   > ![image.png](attachment:d64b03a9-dcdf-4953-9c9b-f19e636d622e.png)

# %%
# 7. 시각화(표)

# %% [markdown]
# ## 8. 시각화(차트) - plot
# * ![image.png](attachment:2aedd1ad-3a56-4e0c-9d28-18cf2ba63371.png) 선택
#   > ![image.png](attachment:1d6dbbc0-5546-450a-939b-4af591975d96.png)

# %%
# 7. 시각화(차트)

# %% [markdown]
# ## 실습
# * 노인의 삶의 질에 대한 평가
# * 파일명: final_pre3.csv
# * 위와 동일한 과정으로 진행해 보자

# %% [markdown]
# ## 1. 데이터 수집
# [Data Analysis] > [File]

# %%
# 1. 데이터 수집 
# 데이터 : final_pre3.csv

# %% [markdown]
# # 2-1.  데이터 전처리(독립변수)  및 train_test_split
# [Data Analysis] > [Frame]

# %%
# 2-1. 데이터 전처리(독립변수) 및 train_test_split

# %% [markdown]
# ## 2-2 데이터 전처리(종속변수) 및 train_test_split
# [Data Analysis]  > [Subset]

# %%
# 2-2. 데이터 전처리(종속변수) 및 train_test_split

# %% [markdown]
# ## 2-3 데이터 전처리 및 train_test_split
# [Machine Learning] > [Data Split]

# %%
# 2-3. 데이터 전처리 및 train_test_split

# %% [markdown]
# ## 3. 모델 생성 (RandomForestClassifiter)
# [Machine Learning] > [Classifier]

# %%
# 3. 모델 생성

# %% [markdown]
# ## 4. 학습 ( fit )
# [Machine Learning] > [Fit/Predict]

# %%
# 4. 학습(fit)

# %% [markdown]
# ## 5. 예측( predict )
# [Machine Learning] > [Fit/Predict]

# %%
# 5. 예측(predict)

# %% [markdown]
# ## 6. 평가 (Evaluation)
# [Machine Learning] > [Evaluation]  : Model(Classification) -> Accuracy

# %%
# 6. 평가(Evaluation) : metrics.accuracy_score(y_test, pred)

# %% [markdown]
# ## 7. 시각화(표)
# * [Machine Learning] > [Model Info] : Model(Classification) -> Info(Feature importances)

# %%
# 7. 시각화(표) : Model(Classification) -> Info(Feature importances)

# %% [markdown]
# ## 8. 시각화(차트)
# * [Machine Learning] > [Model Info] : Model(Classification) -> Info(Plot Feature importances)

# %%
# 8. 시각화(챠트) : Model(Classification) -> Info(Plot Feature importances)

# %% [markdown]
# # (참고사항) 새로운 모델을 이용한 학습/평가 진행 - 파라미터 조정
# * 과적합 문제
# * 성능향상
# * <img src="attachment:b332fa96-4be2-4284-90ad-0b9a5f8c99c6.png" width=850px height=700px />

# %%
# Visual Python: Machine Learning > Classifier
from sklearn.ensemble import RandomForestClassifier

model2 = RandomForestClassifier(n_estimators=300, max_depth=8, min_samples_split=10)

# %%
# Visual Python: Machine Learning > Fit/Predict
model2.fit(X_train, y_train)

# %%
# Visual Python: Machine Learning > Fit/Predict
pred = model2.predict(X_test)
pred

# %%
# Visual Python: Machine Learning > Evaluation
from IPython.display import display, Markdown

# %%
# Visual Python: Machine Learning > Evaluation
# Confusion Matrix
display(Markdown('### Confusion Matrix'))
display(pd.crosstab(y_test, pred, margins=True))

# %%
# Visual Python: Machine Learning > Evaluation
# Classification report
print(metrics.classification_report(y_test, pred))

# %%
# Visual Python: Machine Learning > Evaluation
# Accuracy
print('Accuracy: {}'.format(metrics.accuracy_score(y_test, pred)))

# %%
# Visual Python: Machine Learning > Evaluation
# Precision
print('Precision: {}'.format(metrics.precision_score(y_test, pred, average='weighted')))
